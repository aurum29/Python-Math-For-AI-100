# %% [markdown]
# <a href="https://colab.research.google.com/github/zombe962/Pythoin-Math-For-AI-100/blob/master/3.10.3.%20Output%20image%20file%20using%20CoLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello google colab")
# Out:
# Hello google colab

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e725ab58-fa39-44a7-b331-b17f7de66fee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e725ab58-fa39-44a7-b331-b17f7de66fee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 캡처.PNG to 캡처.PNG

# %%
# !ls -l
# Out:
# total 40
# -rw-r--r-- 1 root root 34070 Feb 13 16:12 캡처.PNG
# drwxr-xr-x 1 root root  4096 Feb 10 14:40 sample_data

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pmg

img = pmg.imread('캡처.PNG')
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show>
